# %% [markdown]
# ### Week 1
# ### DSC 550
# ### Abed Tabbalat

# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset as a Pandas data frame
df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
# Display the first ten rows of data.
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
# Find the dimensions (number of rows and columns) in the data frame. What do these two numbers represent in the context of the data?
print(df.shape)
print(f'We have {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# (16719, 16)
# We have 16719 rows and 16 columns

# %%
# Find the top five games by critic score.
df_critic = df.sort_values(by=['Critic_Score'], ascending=False)
df_critic.head(5)
# Out:
#                           Name Platform  Year_of_Release     Genre  \
# 227   Tony Hawk's Pro Skater 2       PS           2000.0    Sports
# 57         Grand Theft Auto IV      PS3           2008.0    Action
# 51         Grand Theft Auto IV     X360           2008.0    Action
# 5350               SoulCalibur       DC           1999.0  Fighting
# 165         Grand Theft Auto V     XOne           2014.0    Action
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 227             Activision      3.05      1.41      0.02         0.20
# 57    Take-Two Interactive      4.76      3.69      0.44         1.61
# 51    Take-Two Interactive      6.76      3.07      0.14         1.03
# 5350    Namco Bandai Games      0.00      0.00      0.34         0.00
# 165   Take-Two Interactive      2.81      2.19      0.00         0.47
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# ...

# %%
# Find the number of video games in the data frame in each genre.
df_count = df.groupby('Genre').count()
df_count
# Out:
#               Name  Platform  Year_of_Release  Publisher  NA_Sales  EU_Sales  \
# Genre
# Action        3370      3370             3308       3364      3370      3370
# Adventure     1303      1303             1293       1299      1303      1303
# Fighting       849       849              837        847       849       849
# Misc          1750      1750             1721       1723      1750      1750
# Platform       888       888              878        887       888       888
# Puzzle         580       580              569        580       580       580
# Racing        1249      1249             1226       1248      1249      1249
# Role-Playing  1500      1500             1483       1499      1500      1500
# Shooter       1323      1323             1296       1321      1323      1323
# Simulation     874       874              858        870       874       874
# Sports        2348      2348             2306       2345      2348      2348
# ...

# %%
# Find the first five games in the data frame on the SNES platform.
df_snes = df.sort_values(by=['Year_of_Release'])
df_snes = df_snes[df_snes['Platform'] == 'SNES'].head(5)
df_snes
# Out:
#                                   Name Platform  Year_of_Release       Genre  \
# 511                             F-Zero     SNES           1990.0      Racing
# 1791                        Pilotwings     SNES           1990.0  Simulation
# 18                   Super Mario World     SNES           1990.0    Platform
# 1195                       Final Fight     SNES           1990.0      Action
# 6599  Romance of the Three Kingdoms II     SNES           1991.0    Strategy
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 511     Nintendo      1.37      0.51      0.89         0.07          2.85
# 1791    Nintendo      0.46      0.17      0.48         0.02          1.14
# 18      Nintendo     12.78      3.75      3.54         0.55         20.61
# 1195      Capcom      0.67      0.17      0.69         0.03          1.56
# 6599  Tecmo Koei      0.00      0.00      0.25         0.00          0.25
#
# ...

# %%
# Find the five publishers with the highest total global sales. Note: You will need to calculate the total global sales for each publisher to do this.
df_sales = df.groupby('Publisher').sum().reset_index()
df_sales = df_sales[['Publisher', 'Global_Sales']]
df_sales = df_sales.sort_values(by=['Global_Sales'], ascending=False).head(5)
df_sales
# Out:
#                        Publisher  Global_Sales
# 361                     Nintendo       1788.81
# 139              Electronic Arts       1116.96
# 21                    Activision        731.16
# 458  Sony Computer Entertainment        606.48
# 528                      Ubisoft        471.61

# %%
# Create a new column in the data frame that calculates the percentage of global sales from North America. Display the first five rows of the new data frame.
df_ratio = df
df_ratio['NA_Sales_Ratio'] = df_ratio['NA_Sales'] / df_ratio['Global_Sales']
df_ratio.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %%
# Find the number NaN entries (missing data values) in each column.
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# NA_Sales_Ratio        0
# dtype: int64

# %%
# Try to calculate the median user score of all the video games. You will likely run into an error because some of the user score entries are a non-numerical
# string that cannot be converted to a float. Find and replace this string with NaN and then calculate the median. Then, replace all NaN entries in the user
# score column with the median value.
df_median = df
print(f'User_Score type before update: {df_median["User_Score"].dtypes}')

df_median = df_median.replace('tbd', np.nan)
df_median = df_median.astype({'User_Score' : 'float64'})
print(f'User_Score type after update: {df_median["User_Score"].dtypes}')

user_median = df_median['User_Score'].median()
print(f'\nThe median for User_Score is: {user_median}')

df_median = df_median.replace(np.nan, user_median)
print(f'\nNan check for User_Score: {df_median["User_Score"].isna().sum()}')
df_median
# Out:
# User_Score type before update: object
# User_Score type after update: float64
#
# The median for User_Score is: 7.5
#
# Nan check for User_Score: 0
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# ...
